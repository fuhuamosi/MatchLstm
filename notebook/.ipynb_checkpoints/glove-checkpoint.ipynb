# %%
from glove import Glove
from glove import Corpus

# %%
def read_corpus(filename):
    corpus = []
    with open(filename, 'r') as datafile:
        for line in datafile:
            corpus.append(line.strip().split(' '))
    return corpus

# %%
corpus_model = Corpus()

# %%
corpus = read_corpus('../dataset/corpus.txt')

# %%
corpus_model.fit(corpus, window=3)

# %%
glove = Glove(no_components=300)
glove.fit(corpus_model.matrix, epochs=int(20),
          no_threads=8, verbose=True)
# Out:
# Performing 20 training epochs with 8 threads
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Epoch 10
# Epoch 11
# Epoch 12
# Epoch 13
# Epoch 14
# Epoch 15
# Epoch 16
# Epoch 17
# Epoch 18
# Epoch 19

# %%
glove.add_dictionary(corpus_model.dictionary)

# %%
sorted(glove.dictionary, key=glove.dictionary.get, reverse=False)
# Out:
# ['there',
#  'are',
#  'people',
#  'wearing',
#  'pink',
#  'shirts',
#  'two',
#  'boys',
#  'on',
#  'a',
#  'dirt',
#  'road',
#  'kids',
#  'and',
#  'woman',
#  'enjoys',
#  'fire',
#  'hydrant',
#  'splash',
#  'the',
#  'brick',
#  'is',
#  'red',
#  'man',
#  'standing',
#  'while',
#  'filming',
#  'politicians',
#  'lways',
#  'wear',
#  'casuals',
#  'smiling',
#  'walking',
#  'sand',
#  'children',
#  'taking',
#  'part',
#  'in',
#  'icecapades',
#  'three',
#  'girls',
#  'running',
#  'water',
#  'advantage',
#  'of',
#  'nice',
#  'weather',
#  'at',
#  'park',
#  'prostitutes',
#  'soliciting',
#  'customers',
#  'some',
#  'with',
#  'balloon',
#  'creations',
#  'men',
#  'inside',
#  'house',
#  'crowd',
#  'watches',
#  'bmx',
#  'race',
#  'middleaged',
#  'white',
#  'sings',
#  'into',
#  'microphone',
#  'walk',
#  'along',
#  'beach',
#  'shortboarders',
#  'getting',
#  'ready',
#  'to',
#  'enter',
#  'upper',
#  'deck',
#  'british',
#  'bus',
#  'that',
#  'riding',
#  'sitting',
#  'couch',
#  'women',
#  'their',
#  'hands',
#  'raised',
#  'karate',
#  'uniforms',
#  'carrying',
#  'large',
#  'bag',
#  'filled',
#  'substance',
#  'down',
#  'ally',
#  'as',
#  'figure',
#  'walks',
#  'behind',
#  'them',
#  'going',
#  'performance',
#  'dog',
#  'not',
#  'all',
#  'four',
#  'legs',
#  'stewardess',
#  'passing',
#  'out',
#  'dinners',
#  'flight',
#  'dump',
#  'truck',
#  'unloading',
#  'rocks',
#  '3',
#  'watch',
#  'between',
#  'buildings',
#  'girl',
#  'go',
#  'fishing',
#  'uniform',
#  'near',
#  'taxi',
#  'sits',
#  'market',
#  'playing',
#  'scottish',
#  'song',
#  'rides',
#  'an',
#  'atv',
#  'young',
#  'ignoring',
#  'each',
#  'other',
#  'photographing',
#  'reclining',
#  'couple',
#  'verdant',
#  'expanse',
#  'grass',
#  'person',
#  'black',
#  'building',
#  'coming',
#  'window',
#  'dressed',
#  'takes',
#  'stroll',
#  'bench',
#  'ocean',
#  'many',
#  'brides',
#  'line',
#  'up',
#  'street',
#  'boy',
#  'kissing',
#  'by',
#  'lake',
#  'you',
#  'appear',
#  'be',
#  'from',
#  'indian',
#  'descent',
#  'pose',
#  'for',
#  'picture',
#  'look',
#  'happy',
#  'doing',
#  'so',
#  'child',
#  'concert',
#  'group',
#  'soccer',
#  'body',
#  'background',
#  'jogging',
#  'jacket',
#  'pants',
#  'snow',
#  'cap',
#  'builds',
#  'hill',
#  'puts',
#  'stick',
#  'top',
#  'basketballs',
#  'another',
#  'mans',
#  'back',
#  'little',
#  'shorts',
#  'jumps',
#  'stands',
#  'rail',
#  'his',
#  'arms',
#  'outstretched',
#  'jeans',
#  'care',
#  'friends',
#  'dogs',
#  'stuffed',
#  'animals',
#  'school',
#  'holding',
#  'lady',
#  'ride',
#  'horse',
#  'empty',
#  'room',
#  'listen',
#  'mp3',
#  'player',
#  'together',
#  'get',
#  'shirt',
#  'striped',
#  'stripes',
#  'cleaning',
#  'car',
#  'her',
#  'allowance',
#  'money',
#  'outside',
#  'will',
#  'photo',
#  'construction',
#  'worker',
#  'strong',
#  'sleeping',
#  'mexican',
#  'dancing',
#  'fun',
#  'attacking',
#  'boat',
#  'visit',
#  'ancient',
#  'temple',
#  'band',
#  'complete',
#  'darkness',
#  'old',
#  'bluish',
#  'gray',
#  'audience',
#  'watching',
#  'show',
#  'blueshirt',
#  'was',
#  'installing',
#  'cieling',
#  'hardware',
#  'pumpkins',
#  'trampoline',
#  'after',
#  'life',
#  'vest',
#  'makes',
#  'first',
#  'home',
#  'run',
#  'she',
#  'has',
#  'ever',
#  'made',
#  'brothers',
#  'racing',
#  'bikes',
#  'herself',
#  'boots',
#  'video',
#  'games',
#  'locker',
#  'looking',
#  'asian',
#  'colorful',
#  'globe',
#  'roller',
#  'blades',
#  'suit',
#  'moving',
#  'diligently',
#  'speaking',
#  'hat',
#  'front',
#  'bull',
#  'carries',
#  'trash',
#  'touching',
#  'tube',
#  'spirals',
#  'closely',
#  'drinks',
#  'poses',
#  'pictures',
#  'statue',
#  'peple',
#  'trying',
#  'learn',
#  'swiming',
#  'laying',
#  'huddle',
#  'team',
#  'charge',
#  'zebra',
#  'reading',
#  'books',
#  'long',
#  'hair',
#  'meditating',
#  'desk',
#  'restaurant',
#  'waiting',
#  'food',
#  'pithcer',
#  'studies',
#  'something',
#  'beneath',
#  'microscope',
#  'form',
#  'chair',
#  'next',
#  'board',
#  'one',
#  'musical',
#  'instrument',
#  'smoking',
#  'pipe',
#  'blond',
#  'matching',
#  'tshirts',
#  'shooting',
#  'range',
#  'dad',
#  'workers',
#  'play',
#  'music',
#  'sea',
#  'picking',
#  'flowers',
#  'trading',
#  'sausage',
#  'link',
#  'via',
#  'mouth',
#  'females',
#  'sisters',
#  'onlooking',
#  'during',
#  'classical',
#  'socks',
#  'brown',
#  'jumper',
#  'using',
#  'kind',
#  'object',
#  'i',
#  'ca',
#  'nt',
#  'identify',
#  'properly',
#  'monopoly',
#  'lot',
#  'individual',
#  'skiing',
#  'mountain',
#  'african',
#  'soldier',
#  'ak47',
#  'gun',
#  'shoulder',
#  'writes',
#  'letter',
#  'stream',
#  'jungle',
#  'waits',
#  'public',
#  'area',
#  'rock',
#  'musician',
#  'performing',
#  'wet',
#  'alley',
#  'eating',
#  'bowl',
#  'cheerios',
#  'military',
#  'stand',
#  'loaded',
#  'toys',
#  'vendors',
#  'selling',
#  'cookies',
#  'students',
#  'examining',
#  'sheets',
#  'paper',
#  'having',
#  'affair',
#  'pairs',
#  'differentcolored',
#  'underwear',
#  'hanging',
#  'clothesline',
#  'cars',
#  'writing',
#  'story',
#  'older',
#  'plays',
#  'tuba',
#  'asia',
#  'starving',
#  'hoe',
#  'site',
#  'family',
#  'skier',
#  'midjump',
#  'twist',
#  'right',
#  'off',
#  'jump',
#  'lying',
#  'fish',
#  'scrubbing',
#  'bird',
#  'wellrested',
#  'guy',
#  'guitar',
#  'friend',
#  'looks',
#  'him',
#  'work',
#  'move',
#  'slab',
#  'stone',
#  'game',
#  'university',
#  'lawn',
#  'pulls',
#  'suitcasre',
#  'around',
#  'la',
#  'airport',
#  'wheelchair',
#  'fallen',
#  'members',
#  'best',
#  'skateboarders',
#  'stunts',
#  'jumping',
#  'over',
#  'field',
#  'full',
#  'set',
#  'wife',
#  'everything',
#  'can',
#  'seen',
#  'here',
#  'toddlers',
#  'new',
#  'shows',
#  'true',
#  'lack',
#  'skill',
#  'sniffing',
#  'binder',
#  'kid',
#  'making',
#  'grimacing',
#  'face',
#  'wrapped',
#  'towel',
#  'tie',
#  'contact',
#  'lenses',
#  'mutltiple',
#  'small',
#  'tent',
#  'basketball',
#  'overtime',
#  'players',
#  'cleats',
#  'television',
#  'sweatshirts',
#  'jackets',
#  'head',
#  'towards',
#  'attempt',
#  'reach',
#  'ball',
#  'hockey',
#  'jamming',
#  'local',
#  'nightclub',
#  'officers',
#  'handcuff',
#  'put',
#  'squad',
#  'boaters',
#  'have',
#  'taken',
#  'refuge',
#  'marina',
#  'before',
#  'storm',
#  'attempts',
#  'skateboard',
#  'trick',
#  'fountain',
#  'sit',
#  'hurrying',
#  'supermarket',
#  'classroom',
#  'painted',
#  'light',
#  'blue',
#  'happily',
#  'shopping',
#  'through',
#  'woods',
#  'broadly',
#  'holds',
#  'both',
#  'soaking',
#  'it',
#  'nighttime',
#  'driving',
#  'bike',
#  'city',
#  'tall',
#  'paint',
#  'covered',
#  'table',
#  'condiments',
#  'wide',
#  'open',
#  'thinking',
#  'skatepark',
#  'got',
#  'injuries',
#  'naked',
#  'baby',
#  'pacifier',
#  'its',
#  'buttons',
#  'mother',
#  'patient',
#  'picnic',
#  'surrounded',
#  'vehicles',
#  'swims',
#  'laps',
#  'pool',
#  'skateboarder',
#  'tricks',
#  'cooking',
#  'plumes',
#  'dusk',
#  'consulting',
#  'map',
#  'determine',
#  'destination',
#  'silly',
#  'green',
#  'glasses',
#  'confused',
#  'under',
#  'tree',
#  'who',
#  'fell',
#  'asleep',
#  'baskets',
#  'break',
#  'this',
#  'clear',
#  'day',
#  'weeks',
#  'haircut',
#  'beside',
#  'heads',
#  'bent',
#  'cane',
#  'lap',
#  'flying',
#  'grocery',
#  'impatient',
#  'train',
#  'come',
#  'stunt',
#  'stairs',
#  'smiles',
#  'beautiful',
#  'laptop',
#  'computer',
#  'leans',
#  'nude',
#  'blows',
#  'bubbles',
#  'wand',
#  'held',
#  'male',
#  'rollerblader',
#  'grinding',
#  'brunette',
#  'giving',
#  'report',
#  'toward',
#  'camera',
#  'mounted',
#  'steel',
#  'wall',
#  'pet',
#  'owner',
#  'spaniel',
#  'gang',
#  'wears',
#  'dress',
#  'counter',
#  'puppet',
#  'sooners',
#  'football',
#  'moves',
#  'quickly',
#  'runs',
#  'mum',
#  'lunch',
#  'performs',
#  'years',
#  'festival',
#  'surrounding',
#  'telescope',
#  'view',
#  'things',
#  'great',
#  'distance',
#  'caught',
#  'explosion',
#  'presentation',
#  'where',
#  'lighting',
#  'illuminating',
#  'welder',
#  'cries',
#  'being',
#  'punished',
#  'photographs',
#  'tony',
#  'hawk',
#  'skateboarding',
#  'hand',
#  'lots',
#  'enjoying',
#  'pair',
#  'decide',
#  'raft',
#  'across',
#  'river',
#  'rain',
#  'teaching',
#  'class',
#  'chef',
#  'preparing',
#  'favorite',
#  'dish',
#  'kitchen',
#  'which',
#  'yellow',
#  'boxing',
#  'against',
#  'cute',
#  'robe',
#  'leading',
#  'involves',
#  'your',
#  'nurses',
#  'items',
#  'cart',
#  'nike',
#  'logo',
#  'waving',
#  'outdoors',
#  'clothing',
#  'guys',
#  'dark',
#  'store',
#  'employee',
#  'rests',
#  'shelf',
#  'about',
#  'crush',
#  'sanitation',
#  'orange',
#  'clean',
#  'talking',
#  'bros',
#  'played',
#  'display',
#  'groups',
#  'cat',
#  'barn',
#  'leg',
#  'covering',
#  'hold',
#  'pole',
#  'walkway',
#  'restaurants',
#  'ground',
#  'bucket',
#  'practicing',
#  'balance',
#  'beams',
#  'guitars',
#  'classic',
#  'skirt',
#  'tennis',
#  'performer',
#  'singing',
#  'wood',
#  'hotel',
#  'ship',
#  'lit',
#  'squats',
#  'bicycles',
#  'stir',
#  'fry',
#  'cook',
#  'prepares',
#  'grill',
#  'coat',
#  'goat',
#  'wash',
#  'clothes',
#  'laundry',
#  'mat',
#  'share',
#  'laugh',
#  'unique',
#  'costume',
#  'bagpipes',
#  'stare',
#  'paragliding',
#  'shortsleeved',
#  'planted',
#  'motorcyclist',
#  'avenue',
#  'screaming',
#  'wait',
#  'loved',
#  'ones',
#  'returning',
#  'business',
#  'trip',
#  'crew',
#  'labors',
#  'directs',
#  'traffic',
#  'bubble',
#  'maker',
#  'kitchenaid',
#  'appliances',
#  'rider',
#  'hits',
#  'ramp',
#  'does',
#  'famous',
#  'pedistrian',
#  'close',
#  'clearlymarked',
#  'zone',
#  'amongst',
#  'boxers',
#  'competing',
#  'match',
#  'eats',
#  'sheep',
#  'skater',
#  'skates',
#  'nurse',
#  'hospital',
#  'baseball',
#  'surfing',
#  'time',
#  'way',
#  'basket',
#  'badminton',
#  'golf',
#  'place',
#  'single',
#  'rose',
#  'backstroke',
#  'indoor',
#  'upcoming',
#  'swim',
#  'meet',
#  'cigarette',
#  'leaning',
#  'someone',
#  'lesbian',
#  'lovers',
#  'no',
#  'rudder',
#  'bathing',
#  'suits',
#  'spray',
#  'machine',
#  'tag',
#  'onlookers',
#  'call',
#  'cops',
#  'monks',
#  'college',
#  'frat',
#  'party',
#  'forest',
#  'campsite',
#  'located',
#  'among',
#  'trees',
#  'bushes',
#  'sidelines',
#  'signs',
#  'lone',
#  'cross',
#  'snowy',
#  'bank',
#  'comes',
#  'shower',
#  'hangs',
#  'bar',
#  'trumpet',
#  'drinking',
#  'liquid',
#  'competition',
#  'fall',
#  'leaves',
#  'scattered',
#  'side',
#  'grassy',
#  'stuck',
#  'style',
#  'horsedrawn',
#  'wagon',
#  'driven',
#  'derby',
#  'shrubbery',
#  'lined',
#  'path',
#  'expecting',
#  'treat',
#  'hike',
#  'chasing',
#  'chipmunk',
#  'several',
#  'homeless',
#  'sleep',
#  'strollers',
#  'upset',
#  'giorgios',
#  'squirrel',
#  'skirts',
#  'away',
#  'terror',
#  'kindergarden',
#  'napping',
#  'alone',
#  'flute',
#  'spare',
#  'change',
#  'underground',
#  'commuters',
#  'swing',
#  'chinese',
#  'sparklers',
#  'amazed',
#  'lights',
#  'pocketbook',
#  'purple',
#  'do',
#  'throwing',
#  'frisbee',
#  'warrior',
#  'combat',
#  'gentleman',
#  'driveway',
#  'stage',
#  'church',
#  'country',
#  'scene',
#  'sold',
#  'vegetables',
#  'paved',
#  'customer',
#  'sneaking',
#  'chased',
#  'security',
#  'longsleeve',
#  'farmers',
#  'tshirt',
#  'gardener',
#  'distracting',
#  'bicyclists',
#  'gold',
#  'outdoor',
#  'climbing',
#  'groom',
#  'tux',
#  'bride',
#  'sprinkled',
#  'umbrellas',
#  'shield',
#  'staring',
#  'shoes',
#  'certificate',
#  'bandanna',
#  'dart',
#  'aired',
#  'screen',
#  'past',
#  '4',
#  'swimming',
#  'seal',
#  'speech',
#  'overalls',
#  'packed',
#  'husband',
#  'swiss',
#  'alps',
#  'dives',
#  'agent',
#  'door',
#  'frame',
#  'colored',
#  'vending',
#  'shop',
#  'falls',
#  'surfboard',
#  'grilling',
#  'camels',
#  'musicians',
#  'six',
#  'pushing',
#  'wooden',
#  'wheel',
#  'tiger',
#  'zoo',
#  'wakeboarding',
#  'posing',
#  'wedding',
#  'workman',
#  'mask',
#  'cutting',
#  '2x4s',
#  'undocked',
#  'toy',
#  'birds',
#  'rome',
#  'see',
#  'pope',
#  'ordering',
#  'choir',
#  'silent',
#  'they',
#  'director',
#  'ladies',
#  'makeup',
#  'done',
#  'applying',
#  'closest',
#  'brush',
#  'filling',
#  'twoliter',
#  'bottle',
#  'garage',
#  'dinosaurs',
#  'balcony',
#  'ski',
#  'feeding',
#  'seagulls',
#  'adults',
#  'farming',
#  'metal',
#  'fence',
#  'roadwork',
#  'follows',
#  'elderly',
#  'bonfire',
#  'talk',
#  'only',
#  'certain',
#  'kinds',
#  ...]

# %%
glove.most_similar('study', number=10)
# Out:
# [('was', 0.80271845746944193),
#  ('there', 0.72662131803516328),
#  ('were', 0.70493933097513939),
#  ('who', 0.68238095354074702),
#  ('guy', 0.67574789892022724),
#  ('young', 0.66308395641981099),
#  ('sad', 0.65951639071643409),
#  ('boy', 0.6473715881868457),
#  ('kid', 0.64290610515867019)]
