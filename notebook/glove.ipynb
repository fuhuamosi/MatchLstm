# %%
from glove import Glove
from glove import Corpus

# %%
def read_corpus(filename):
    corpus = []
    with open(filename, 'r') as datafile:
        for line in datafile:
            corpus.append(line.strip().split(' '))
    return corpus

# %%
corpus_model = Corpus()

# %%
corpus = read_corpus('../dataset/corpus.txt')

# %%
corpus_model.fit(corpus, window=5)

# %%
glove = Glove(no_components=300)
glove.fit(corpus_model.matrix, epochs=int(20),
          no_threads=8, verbose=True)
# Out:
# Performing 20 training epochs with 8 threads
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Epoch 10
# Epoch 11
# Epoch 12
# Epoch 13
# Epoch 14
# Epoch 15
# Epoch 16
# Epoch 17
# Epoch 18
# Epoch 19

# %%
glove.add_dictionary(corpus_model.dictionary)

# %%
sorted(glove.dictionary, key=glove.dictionary.get, reverse=False)
# Out:
# ['someone',
#  'is',
#  'sunbathing',
#  'front',
#  'stroke',
#  'swimming',
#  'race',
#  'roped',
#  'off',
#  'lap',
#  'areas',
#  'a',
#  'group',
#  'of',
#  'people',
#  'are',
#  'hanging',
#  'on',
#  'sidewalk',
#  'person',
#  'the',
#  'baseball',
#  'player',
#  'irish',
#  'made',
#  'an',
#  'out',
#  'woman',
#  'asleep',
#  'in',
#  'church',
#  'scientist',
#  'peering',
#  'through',
#  'microscope',
#  'jumps',
#  'near',
#  'cactus',
#  'guy',
#  'suit',
#  'playing',
#  'trumpet',
#  'little',
#  'girl',
#  'holds',
#  'pair',
#  'head',
#  'phones',
#  'after',
#  'finding',
#  'them',
#  'when',
#  'she',
#  'thought',
#  'lost',
#  'lone',
#  'cyclist',
#  'powers',
#  'muddy',
#  'trail',
#  'forest',
#  'child',
#  'with',
#  's',
#  'orange',
#  'snow',
#  'shovel',
#  'shovels',
#  'there',
#  'female',
#  'singer',
#  'two',
#  'blond',
#  'dogs',
#  'standing',
#  'together',
#  'patio',
#  'couch',
#  'eating',
#  'christmas',
#  'candy',
#  'other',
#  'women',
#  'listen',
#  'as',
#  'bridetobe',
#  'thanks',
#  'for',
#  'being',
#  'her',
#  'bridesmaids',
#  'they',
#  'young',
#  'tomato',
#  'plants',
#  'man',
#  'eats',
#  'chocolate',
#  'ice',
#  'cream',
#  'cone',
#  'reflective',
#  'safety',
#  'clothes',
#  'drives',
#  'branded',
#  'john',
#  'deere',
#  'tractor',
#  'throwing',
#  'ball',
#  'at',
#  'pile',
#  'blocks',
#  'stuffed',
#  'animals',
#  'background',
#  'redhead',
#  'sleeping',
#  'stage',
#  'kid',
#  'wearing',
#  'warmup',
#  'and',
#  'looking',
#  'sky',
#  'one',
#  'hot',
#  'air',
#  'balloon',
#  'hollywood',
#  'walk',
#  'fame',
#  'climbing',
#  'stream',
#  'animal',
#  'kicking',
#  'up',
#  'dust',
#  'while',
#  'dressed',
#  'bright',
#  'blue',
#  'red',
#  'sits',
#  'green',
#  'grass',
#  'dog',
#  'carrying',
#  'pink',
#  'its',
#  'mouth',
#  'alone',
#  'car',
#  'was',
#  'luggage',
#  'plays',
#  'jazz',
#  'music',
#  'sign',
#  'building',
#  'historic',
#  'landmark',
#  'watching',
#  'outside',
#  'glasses',
#  'leans',
#  'reading',
#  'book',
#  'family',
#  'petting',
#  'zoo',
#  'children',
#  'play',
#  'sand',
#  'kids',
#  'granny',
#  'smiths',
#  'posing',
#  'camera',
#  'steps',
#  'younger',
#  'bearded',
#  'contacts',
#  'comic',
#  'closed',
#  'laptop',
#  'possibly',
#  'store',
#  'seven',
#  'by',
#  'decorated',
#  'stone',
#  'pillars',
#  'street',
#  'sleeps',
#  'waiting',
#  'room',
#  'boy',
#  'next',
#  'to',
#  'display',
#  'flipflop',
#  'shoes',
#  'dress',
#  'horse',
#  'walking',
#  'having',
#  'conversation',
#  'shirt',
#  'acts',
#  'shy',
#  'picture',
#  'him',
#  'taken',
#  'some',
#  'welders',
#  'working',
#  'dark',
#  'yellow',
#  'jacket',
#  'stands',
#  'shore',
#  'testing',
#  'water',
#  'his',
#  'rubber',
#  'boot',
#  'clad',
#  'toe',
#  'checkered',
#  'coat',
#  'walks',
#  'down',
#  'hallway',
#  'followed',
#  'another',
#  'cars',
#  'great',
#  'outdoors',
#  'small',
#  'chilcren',
#  'give',
#  'eachother',
#  'piggyback',
#  'rides',
#  'window',
#  'tub',
#  'resting',
#  'outer',
#  'roof',
#  'flags',
#  'attached',
#  'ready',
#  'take',
#  'rally',
#  'smiling',
#  'hold',
#  'furry',
#  'football',
#  'players',
#  'hike',
#  'formation',
#  'jams',
#  'bass',
#  'guitar',
#  'sunny',
#  'yard',
#  'boys',
#  'eat',
#  'dinner',
#  'home',
#  'snowy',
#  'field',
#  'four',
#  'gym',
#  'this',
#  'white',
#  'hard',
#  'hat',
#  'gray',
#  'vest',
#  'longsleeve',
#  'top',
#  'men',
#  'diving',
#  'bald',
#  'sets',
#  'dj',
#  'gig',
#  'chef',
#  'their',
#  'bikes',
#  'print',
#  'table',
#  'filled',
#  'papers',
#  'underneath',
#  'bridge',
#  'turns',
#  'away',
#  'from',
#  'beach',
#  'foot',
#  'boogie',
#  'board',
#  'surfboard',
#  'navigates',
#  'waves',
#  'ocean',
#  'blonde',
#  'haired',
#  'cries',
#  'behind',
#  'bar',
#  'male',
#  'sleds',
#  'sheet',
#  'plastic',
#  'smile',
#  'face',
#  'hair',
#  'blowing',
#  'back',
#  'sun',
#  'bathing',
#  'crowd',
#  'goes',
#  'tent',
#  'special',
#  'items',
#  'purchase',
#  'holding',
#  'vegetables',
#  'dentists',
#  'doing',
#  'surgery',
#  'patient',
#  'tie',
#  'frowning',
#  'pushing',
#  'empty',
#  'stroller',
#  'today',
#  'getting',
#  'taking',
#  'pictures',
#  'jewelry',
#  'garage',
#  'it',
#  'be',
#  'open',
#  'bunch',
#  'run',
#  'past',
#  'surfers',
#  'inside',
#  'office',
#  'flies',
#  'mars',
#  'tomorrow',
#  'father',
#  'son',
#  'shoulders',
#  'makes',
#  'funny',
#  'just',
#  'took',
#  'bath',
#  'ladies',
#  'roller',
#  'coaster',
#  'ride',
#  'bare',
#  'hands',
#  'ax',
#  'teams',
#  'trying',
#  'win',
#  'van',
#  'talking',
#  'runner',
#  'safe',
#  'plate',
#  'youth',
#  'game',
#  'lollipop',
#  'riding',
#  'lawn',
#  'mower',
#  '3',
#  'year',
#  'old',
#  'present',
#  'morning',
#  'couple',
#  'males',
#  'instrument',
#  'trained',
#  'riders',
#  'muzzle',
#  'running',
#  'jumping',
#  'daughter',
#  'admits',
#  'that',
#  'mom',
#  'cool',
#  'aviator',
#  'sunglasses',
#  'librarians',
#  'smoke',
#  'break',
#  'market',
#  'something',
#  'buy',
#  'indoor',
#  'makeup',
#  'bottle',
#  'indoors',
#  'draws',
#  'elk',
#  'canoe',
#  'rocky',
#  'black',
#  'collar',
#  'watches',
#  'ferret',
#  'purple',
#  'heels',
#  'asian',
#  'somewhere',
#  'loaded',
#  'trailer',
#  'crew',
#  'bends',
#  'speak',
#  'workers',
#  'hats',
#  'ledge',
#  'sit',
#  'emtpy',
#  'road',
#  'sitting',
#  'selling',
#  'lemonade',
#  'watermelon',
#  'slices',
#  'runs',
#  'shopping',
#  'cart',
#  'tank',
#  'shorts',
#  'newspaper',
#  'carries',
#  'bucket',
#  'many',
#  'least',
#  'playground',
#  'went',
#  'plumber',
#  'tries',
#  'unclog',
#  'sink',
#  'friends',
#  'look',
#  'bike',
#  'too',
#  'big',
#  'doctors',
#  'washing',
#  'not',
#  'toothbrush',
#  'cafe',
#  'dirt',
#  'servers',
#  'pass',
#  'menus',
#  'patrons',
#  'owner',
#  'park',
#  'older',
#  'follows',
#  'girls',
#  'firefighters',
#  'were',
#  'first',
#  'arrive',
#  'scene',
#  'stopped',
#  'go',
#  'across',
#  'sort',
#  'celebration',
#  'maybe',
#  'wedding',
#  'large',
#  'dimly',
#  'lit',
#  'skier',
#  'skiing',
#  'slopes',
#  'teenager',
#  'hockey',
#  'has',
#  'fallen',
#  'abusive',
#  'boyfriend',
#  'cow',
#  'leaves',
#  'fountain',
#  'watch',
#  'who',
#  'throw',
#  'pennies',
#  'into',
#  'three',
#  'lady',
#  'motorcycle',
#  'crossing',
#  'crosswalk',
#  'smoking',
#  'cigar',
#  'barn',
#  'milk',
#  'cows',
#  'arrived',
#  'city',
#  'coach',
#  'gets',
#  'drink',
#  'going',
#  'peace',
#  'symbol',
#  'grills',
#  'dancing',
#  'crowded',
#  'crop',
#  'corn',
#  'belly',
#  'outfit',
#  'bending',
#  'over',
#  'backwards',
#  'dryer',
#  'dry',
#  'owns',
#  'tourist',
#  'stand',
#  'london',
#  'painting',
#  'woods',
#  'house',
#  'blurry',
#  'photo',
#  'bench',
#  'square',
#  'dancers',
#  'will',
#  'mall',
#  'discussing',
#  'business',
#  'seemingly',
#  'place',
#  'catch',
#  'africanamerican',
#  'electric',
#  'public',
#  'base',
#  'got',
#  'score',
#  'team',
#  'here',
#  'truck',
#  'wheels',
#  'pushes',
#  'new',
#  'guns',
#  'bought',
#  'yesterday',
#  'hunting',
#  'trip',
#  'metal',
#  'hobo',
#  'nap',
#  'failed',
#  'interview',
#  'delivering',
#  'yoga',
#  'mat',
#  'singing',
#  'love',
#  'song',
#  'river',
#  'fog',
#  'musical',
#  'even',
#  'happening',
#  'protesters',
#  'political',
#  'signs',
#  'gathering',
#  'postman',
#  'using',
#  'action',
#  'strikes',
#  'tennis',
#  'underwater',
#  'goggles',
#  'works',
#  'construction',
#  'brown',
#  'stick',
#  'covered',
#  'fake',
#  'blood',
#  'desk',
#  'screen',
#  'projection',
#  'cleans',
#  'railing',
#  'jeans',
#  'stairs',
#  'bus',
#  'backpack',
#  'food',
#  'along',
#  'full',
#  'snacks',
#  'tour',
#  'guide',
#  'wore',
#  'cap',
#  'he',
#  'pointed',
#  'listing',
#  'rules',
#  'passengers',
#  'lake',
#  'puppy',
#  'carpet',
#  'nature',
#  'checking',
#  'piece',
#  'art',
#  'local',
#  'museum',
#  'handling',
#  'fishing',
#  'net',
#  'cross',
#  'mail',
#  'embracing',
#  'caution',
#  'tape',
#  'camel',
#  'computer',
#  'monitor',
#  'relax',
#  'around',
#  'community',
#  'squirt',
#  'each',
#  'gravel',
#  'surface',
#  'sats',
#  'colorful',
#  'jobs',
#  'making',
#  'cookies',
#  'rakes',
#  'unfinished',
#  'greenhouse',
#  'presents',
#  'expensive',
#  'skateboard',
#  'basket',
#  'hovers',
#  'middle',
#  'concrete',
#  'courthouse',
#  'all',
#  'clothing',
#  'shoveling',
#  'toddler',
#  'butterflies',
#  'bookbag',
#  'unsavory',
#  'part',
#  'town',
#  'sunset',
#  'hikers',
#  'tired',
#  'winter',
#  'these',
#  'train',
#  'rider',
#  'attended',
#  'hula',
#  'hoop',
#  'basketball',
#  'finished',
#  'cake',
#  'drinking',
#  'daughters',
#  'bars',
#  'homeless',
#  'cut',
#  'tree',
#  'artist',
#  'herself',
#  'wall',
#  'giant',
#  'painted',
#  'himself',
#  'scotsman',
#  'try',
#  'busy',
#  'seen',
#  'crying',
#  'bicyclist',
#  'helmet',
#  'both',
#  'talk',
#  'cellphones',
#  'favorite',
#  'sick',
#  'baby',
#  'hospital',
#  'bed',
#  'leaving',
#  'station',
#  'nearby',
#  'mothers',
#  'hand',
#  'menu',
#  'restaurant',
#  'depressed',
#  'slot',
#  'machine',
#  'emergency',
#  'worker',
#  'moving',
#  'vehicle',
#  'climbs',
#  'rock',
#  'extension',
#  'cord',
#  'bottom',
#  'under',
#  'night',
#  'few',
#  'scooters',
#  'cliff',
#  'toy',
#  'soldier',
#  'armys',
#  'marching',
#  'band',
#  'others',
#  'participate',
#  'audience',
#  'human',
#  'tourists',
#  'get',
#  'path',
#  'tents',
#  'chair',
#  'wait',
#  'parents',
#  'pick',
#  'takes',
#  'engagement',
#  'pics',
#  'biker',
#  'racing',
#  'keep',
#  'runners',
#  'police',
#  'motorycycle',
#  'showing',
#  'ring',
#  'owners',
#  'else',
#  'anna',
#  'several',
#  'streets',
#  'none',
#  'tea',
#  'kettle',
#  'twin',
#  'teenage',
#  'fighting',
#  'driving',
#  'land',
#  'cruiser',
#  'cold',
#  'performers',
#  'acting',
#  'setting',
#  'chairs',
#  'porkpie',
#  'buffing',
#  'statue',
#  'ridden',
#  'shantytown',
#  'lined',
#  'sing',
#  'buckets',
#  'observing',
#  'put',
#  'naked',
#  'athlete',
#  'nothing',
#  'lunch',
#  'dirty',
#  'cat',
#  'training',
#  'mountain',
#  'highchair',
#  'spongebob',
#  'five',
#  'enjoy',
#  'fisherman',
#  'plain',
#  'tshirt',
#  'extremely',
#  'skater',
#  'does',
#  'trick',
#  'walkway',
#  'fish',
#  'dozen',
#  'screens',
#  'work',
#  'creek',
#  'wrestlers',
#  'high',
#  'school',
#  'wrestling',
#  'only',
#  'tops',
#  'phone',
#  'surfer',
#  'scarf',
#  'whilst',
#  'sports',
#  'hoodies',
#  'facing',
#  'same',
#  'way',
#  'onto',
#  'bring',
#  'boats',
#  'consumes',
#  'treat',
#  'reaching',
#  'picked',
#  'tucking',
#  'accordion',
#  'tips',
#  'walkways',
#  'leads',
#  'dead',
#  'end',
#  'worried',
#  'about',
#  'redhair',
#  'third',
#  'attending',
#  'function',
#  'rigging',
#  'ship',
#  'floor',
#  'clouds',
#  'goalie',
#  'good',
#  'knitting',
#  'site',
#  'enjoying',
#  'every',
#  'move',
#  'hiking',
#  'cats',
#  'tables',
#  'responding',
#  'tan',
#  'trees',
#  'trombone',
#  'performs',
#  'concert',
#  'cigarette',
#  'dad',
#  'library',
#  'drilling',
#  'hole',
#  'lives',
#  'miami',
#  'tricks',
#  'trampoline',
#  'nurses',
#  'have',
#  'picnic',
#  'splash',
#  'paint',
#  'asks',
#  'parade',
#  'start',
#  'beside',
#  'pots',
#  'heads',
#  'teacher',
#  'preparing',
#  'class',
#  'lessons',
#  'shooting',
#  'bow',
#  'arrow',
#  'lot',
#  'congested',
#  'never',
#  'talked',
#  'gambling',
#  'party',
#  'musician',
#  'harmonica',
#  'gold',
#  'costume',
#  'stages',
#  'sitin',
#  'power',
#  'company',
#  'following',
#  'banging',
#  'door',
#  'magnifying',
#  'glass',
#  'stepping',
#  'stones',
#  'pirate',
#  'happy',
#  'engineer',
#  'readings',
#  'staring',
#  'ground',
#  'item',
#  'breakfast',
#  'practicing',
#  'upcoming',
#  'different',
#  'directions',
#  'gift',
#  'blocked',
#  'soccer',
#  'cheeseburger',
#  'advertisement',
#  'measures',
#  'licking',
#  'fingers',
#  'waving',
#  'guys',
#  'help',
#  'wears',
#  'uniform',
#  'hide',
#  'seek',
#  'pajamas',
#  'obviously',
#  'soon',
#  'labrador',
#  'retriever',
#  'subway',
#  'naps',
#  'lays',
#  'manicure',
#  'parked',
#  'touches',
#  'traffic',
#  'pretend',
#  'marriage',
#  'care',
#  'equipment',
#  'very',
#  'strong',
#  'martial',
#  'arts',
#  'discipline',
#  'bird',
#  'nest',
#  'elderly',
#  'boat',
#  'nice',
#  'lush',
#  'forestry',
#  'instruments',
#  'set',
#  'knitted',
#  'line',
#  'vehicles',
#  'horseback',
#  ...]

# %%
glove.most_similar('you', number=10)
# Out:
# [('can', 0.85619169223908864),
#  ('see', 0.85133538447663726),
#  ('we', 0.79309412701766102),
#  ('should', 0.78335896236783764),
#  ('if', 0.76175456468115432),
#  ('could', 0.73469420137432218),
#  ('may', 0.72697734569949279),
#  ('soon', 0.71194457770575403),
#  ('might', 0.70711222000912488)]
